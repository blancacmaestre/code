# %% [markdown]
# # PLOT OF INCLINATION TESTS

# %%
import numpy as np
from astropy.table import Table 
import matplotlib.pyplot as plt
from pastamarkers import markers
palettes = {
    "Colorblind-Friendly": [
        '#0072B2', '#D55E00', '#009E73', '#CC79A7', 
        '#F0E442', '#56B4E9', '#E69F00', '#999999', '#000000'
    ],
    "Bright and Vibrant": [
        '#E41A1C', '#377EB8', '#4DAF4A', '#984EA3', 
        '#FF7F00', '#FFFF33', '#A65628', '#F781BF', '#999999'
    ],
    "Pastel and Soft": [
        '#66C2A5', '#FC8D62', '#8DA0CB', '#E78AC3', 
        '#A6D854', '#FFD92F', '#E5C494', '#B3B3B3', '#D1C4E9'
    ],
    "Monochrome-Inspired": [
        '#08306B', '#08519C', '#2171B5', '#4292C6', 
        '#6BAED6', '#9ECAE1', '#C6DBEF', '#DEEBF7', '#F7FBFF'
    ],
    "Nature-Inspired": [
        '#A6761D', '#1B9E77', '#D95F02', '#7570B3', 
        '#E7298A', '#66A61E', '#E6AB02', '#A6CEE3', '#6A3D9A'
    ]
}

col =  ['#8B4513', '#1B9E77', '#D95F02', '#7570B3', '#E7298A', '#66A61E', '#E6AB02', '#A6761D', '#117733']

# %% [markdown]
# ## INCLINATION TESTS FOR CONSTANT VELOCITY DISPERSION

# %%
#INITIAL INCLINATION (50.988)

input_c_vdisp = "/Users/blanca/Documents/TESIS/software/code/models/model4_params.txt"
inpc = Table.read(input_c_vdisp,format='ascii')

#Only VROT and VDISP free

vdisp_con_360 = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_con_360/barbamodel/barbamodel_params.txt"
a = Table.read(vdisp_con_360,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_con_360/errors.txt"
a = Table.read(vdisp_con_360_err,format='ascii')
a_vrot = a[np.char.find(a['Parameter'], 'vrot') >= 0]
a_vrot["Radius"] = a_vrot["Radius"].astype(float)
a_vdisp = a[np.char.find(a['Parameter'], 'vdisp') >= 0]
a_vdisp["Radius"] = a_vdisp["Radius"].astype(float)

#VROT, VDISP, INC, PA and CENTRE free

vdisp_con_360_free = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_con_360_free/barbamodel/barbamodel_params.txt"
b = Table.read(vdisp_con_360_free,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_con_360_free/errors.txt"
b = Table.read(vdisp_con_360_err,format='ascii')
b_vrot = b[np.char.find(b['Parameter'], 'vrot') >= 0]
b_vrot["Radius"] = b_vrot["Radius"].astype(float)
b_vdisp = b[np.char.find(b['Parameter'], 'vdisp') >= 0]
b_vdisp["Radius"] = b_vdisp["Radius"].astype(float)

#Only VROT, VDISP, INC and PA free, and INC BOUNDS [0,90]

vdisp_con_360_incfree = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_incfree/barbamodel/barbamodel_params.txt"
c = Table.read(vdisp_con_360_incfree,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_incfree/errors.txt"
c = Table.read(vdisp_con_360_err,format='ascii')
c_vrot = c[np.char.find(c['Parameter'], 'vrot') >= 0]
c_vrot["Radius"] = c_vrot["Radius"].astype(float)
c_vdisp = c[np.char.find(c['Parameter'], 'vdisp') >= 0]
c_vdisp["Radius"] = c_vdisp["Radius"].astype(float)

# %%
#INCLINATION 35

#Only VROT and VDISP free

vdisp_con_360 = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_35/barbamodel/barbamodel_params.txt"
d = Table.read(vdisp_con_360,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_35/errors.txt"
d = Table.read(vdisp_con_360_err,format='ascii')
d_vrot = d[np.char.find(d['Parameter'], 'vrot') >= 0]
d_vrot["Radius"] = d_vrot["Radius"].astype(float)
d_vdisp = d[np.char.find(d['Parameter'], 'vdisp') >= 0]
d_vdisp["Radius"] = d_vdisp["Radius"].astype(float)

#VROT, VDISP, INC, PA and CENTRE free

vdisp_con_360_free = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_35_free/barbamodel/barbamodel_params.txt"
e = Table.read(vdisp_con_360_free,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_35_free/errors.txt"
e = Table.read(vdisp_con_360_err,format='ascii')
e_vrot = e[np.char.find(e['Parameter'], 'vrot') >= 0]
e_vrot["Radius"] = e_vrot["Radius"].astype(float)
e_vdisp = e[np.char.find(e['Parameter'], 'vdisp') >= 0]
e_vdisp["Radius"] = e_vdisp["Radius"].astype(float)

#Only VROT, VDISP, INC and PA free, and INC BOUNDS [0,90]

vdisp_con_360_incfree = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_35_incfree/barbamodel/barbamodel_params.txt"
f = Table.read(vdisp_con_360_incfree,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_35_incfree/errors.txt"
f = Table.read(vdisp_con_360_err,format='ascii')
f_vrot = f[np.char.find(f['Parameter'], 'vrot') >= 0]
f_vrot["Radius"] = f_vrot["Radius"].astype(float)
f_vdisp = f[np.char.find(f['Parameter'], 'vdisp') >= 0]
f_vdisp["Radius"] = f_vdisp["Radius"].astype(float)

# %%
#INCLINATION 70

#Only VROT and VDISP free

vdisp_con_360 = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_70/barbamodel/barbamodel_params.txt"
g = Table.read(vdisp_con_360,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_70/errors.txt"
g = Table.read(vdisp_con_360_err,format='ascii')
g_vrot = g[np.char.find(g['Parameter'], 'vrot') >= 0]
g_vrot["Radius"] = g_vrot["Radius"].astype(float)
g_vdisp = g[np.char.find(g['Parameter'], 'vdisp') >= 0]
g_vdisp["Radius"] = g_vdisp["Radius"].astype(float)

#VROT, VDISP, INC, PA and CENTRE free

vdisp_con_360_free = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_70_free/barbamodel/barbamodel_params.txt"
h = Table.read(vdisp_con_360_free,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_70_free/errors.txt"
h = Table.read(vdisp_con_360_err,format='ascii')
h_vrot = h[np.char.find(h['Parameter'], 'vrot') >= 0]
h_vrot["Radius"] = h_vrot["Radius"].astype(float)
h_vdisp = h[np.char.find(h['Parameter'], 'vdisp') >= 0]
h_vdisp["Radius"] = h_vdisp["Radius"].astype(float)

#Only VROT, VDISP, INC and PA free, and INC BOUNDS [0,90]

vdisp_con_360_incfree = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_70_incfree/barbamodel/barbamodel_params.txt"
i = Table.read(vdisp_con_360_incfree,format='ascii')
#ERROR CALCULATION
vdisp_con_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_con_360_70_incfree/errors.txt"
i = Table.read(vdisp_con_360_err,format='ascii')
i_vrot = i[np.char.find(i['Parameter'], 'vrot') >= 0]
i_vrot["Radius"] = i_vrot["Radius"].astype(float)
i_vdisp = i[np.char.find(i['Parameter'], 'vdisp') >= 0]
i_vdisp["Radius"] = i_vdisp["Radius"].astype(float)

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

# Define offsets for clarity
offsets = [-20, -15, -10, -5, 0, 5, 10, 15, 20]

# Velocity curve plot
ax[0].plot(inpc['RADII'], inpc['VROT'], color='black', linewidth=2, label='input')
ax[0].errorbar(a_vrot["Radius"] + offsets[0], a_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[a_vrot["Error_Low"], a_vrot["Error_Up"]], label='fixed 51', color=col[0])
ax[0].errorbar(b_vrot["Radius"] + offsets[1], b_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[b_vrot["Error_Low"], b_vrot["Error_Up"]], label='free 51', color=col[1])
ax[0].errorbar(c_vrot["Radius"] + offsets[2], c_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[c_vrot["Error_Low"], c_vrot["Error_Up"]], label='inc free 51', color=col[2])
ax[0].errorbar(d_vrot["Radius"] + offsets[3], d_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[d_vrot["Error_Low"], d_vrot["Error_Up"]], label='fixed 35', color=col[3])
ax[0].errorbar(e_vrot["Radius"] + offsets[4], e_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[e_vrot["Error_Low"], e_vrot["Error_Up"]], label='free 35', color=col[4])
ax[0].errorbar(f_vrot["Radius"] + offsets[5], f_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[f_vrot["Error_Low"], f_vrot["Error_Up"]], label='inc free 35', color=col[5])
ax[0].errorbar(g_vrot["Radius"] + offsets[6], g_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[g_vrot["Error_Low"], g_vrot["Error_Up"]], label='fixed 70', color=col[6])
ax[0].errorbar(h_vrot["Radius"] + offsets[7], h_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[h_vrot["Error_Low"], h_vrot["Error_Up"]], label='free 70', color=col[7])
ax[0].errorbar(i_vrot["Radius"] + offsets[8], i_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[i_vrot["Error_Low"], i_vrot["Error_Up"]], label='inc free 70', color=col[8])
ax[0].set_xlabel('Radius (arcsec)')
ax[0].set_ylabel('Rotational velocity (km/s)')
ax[0].legend(fontsize="x-large")

# Dispersion plot
ax[1].plot(inpc['RADII'], inpc['VDISP'], color='black', linewidth=2, label='input')
ax[1].errorbar(a_vdisp["Radius"] + offsets[0], a_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[a_vdisp["Error_Low"], a_vdisp["Error_Up"]], label='fixed 51', color=col[0])
ax[1].errorbar(b_vdisp["Radius"] + offsets[1], b_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[b_vdisp["Error_Low"], b_vdisp["Error_Up"]], label='free 51', color=col[1])
ax[1].errorbar(c_vdisp["Radius"] + offsets[2], c_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[c_vdisp["Error_Low"], c_vdisp["Error_Up"]], label='inc free 51', color=col[2])
ax[1].errorbar(d_vdisp["Radius"] + offsets[3], d_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[d_vdisp["Error_Low"], d_vdisp["Error_Up"]], label='fixed 35', color=col[3])
ax[1].errorbar(e_vdisp["Radius"] + offsets[4], e_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[e_vdisp["Error_Low"], e_vdisp["Error_Up"]], label='free 35', color=col[4])
ax[1].errorbar(f_vdisp["Radius"] + offsets[5], f_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[f_vdisp["Error_Low"], f_vdisp["Error_Up"]], label='inc free 35', color=col[5])
ax[1].errorbar(g_vdisp["Radius"] + offsets[6], g_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[g_vdisp["Error_Low"], g_vdisp["Error_Up"]], label='fixed 70', color=col[6])
ax[1].errorbar(h_vdisp["Radius"] + offsets[7], h_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[h_vdisp["Error_Low"], h_vdisp["Error_Up"]], label='free 70', color=col[7])
ax[1].errorbar(i_vdisp["Radius"] + offsets[8], i_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[i_vdisp["Error_Low"], i_vdisp["Error_Up"]], label='inc free 70', color=col[8])
ax[1].set_ylim(0, 40)
ax[1].set_xlabel('Radius (arcsec)')
ax[1].set_ylabel('Dispersion velocity (km/s)')
ax[1].legend(fontsize="x-large")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## INCLINATION TESTS FOR LINEARLY DECREASING VELOCITY DISPERSION

# %%
#INITIAL INCLINATION (50.988)

input_l_vdisp = "/Users/blanca/Documents/TESIS/software/code/models/model3_params.txt"
inpl = Table.read(input_l_vdisp,format='ascii')

#Only VROT and VDISP free

vdisp_lin_360 = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_lin_360/barbamodel/barbamodel_params.txt"
a = Table.read(vdisp_lin_360,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_lin_360/errors.txt"
a = Table.read(vdisp_lin_360_err,format='ascii')
a_vrot = a[np.char.find(a['Parameter'], 'vrot') >= 0]
a_vrot["Radius"] = a_vrot["Radius"].astype(float)
a_vdisp = a[np.char.find(a['Parameter'], 'vdisp') >= 0]
a_vdisp["Radius"] = a_vdisp["Radius"].astype(float)

#VROT, VDISP, INC, PA and CENTRE free

vdisp_lin_360_free = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_lin_360_free/barbamodel/barbamodel_params.txt"
b = Table.read(vdisp_lin_360_free,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_lin_360_free/errors.txt"
b = Table.read(vdisp_lin_360_err,format='ascii')
b_vrot = b[np.char.find(b['Parameter'], 'vrot') >= 0]
b_vrot["Radius"] = b_vrot["Radius"].astype(float)
b_vdisp = b[np.char.find(b['Parameter'], 'vdisp') >= 0]
b_vdisp["Radius"] = b_vdisp["Radius"].astype(float)

#Only VROT, VDISP, INC and PA free, and INC BOUNDS [0,90]

vdisp_lin_360_incfree = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_incfree/barbamodel/barbamodel_params.txt"
c = Table.read(vdisp_lin_360_incfree,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_incfree/errors.txt"
c = Table.read(vdisp_lin_360_err,format='ascii')
c_vrot = c[np.char.find(c['Parameter'], 'vrot') >= 0]
c_vrot["Radius"] = c_vrot["Radius"].astype(float)
c_vdisp = c[np.char.find(c['Parameter'], 'vdisp') >= 0]
c_vdisp["Radius"] = c_vdisp["Radius"].astype(float)

# %%
#INCLINATION 35

#Only VROT and VDISP free

vdisp_lin_360 = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35/barbamodel/barbamodel_params.txt"
d = Table.read(vdisp_lin_360,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35/errors.txt"
d = Table.read(vdisp_lin_360_err,format='ascii')
d_vrot = d[np.char.find(d['Parameter'], 'vrot') >= 0]
d_vrot["Radius"] = d_vrot["Radius"].astype(float)
d_vdisp = d[np.char.find(d['Parameter'], 'vdisp') >= 0]
d_vdisp["Radius"] = d_vdisp["Radius"].astype(float)

#VROT, VDISP, INC, PA and CENTRE free

vdisp_lin_360_free = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35_free/barbamodel/barbamodel_params.txt"
e = Table.read(vdisp_lin_360_free,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35_free/errors.txt"
e = Table.read(vdisp_lin_360_err,format='ascii')
e_vrot = e[np.char.find(e['Parameter'], 'vrot') >= 0]
e_vrot["Radius"] = e_vrot["Radius"].astype(float)
e_vdisp = e[np.char.find(e['Parameter'], 'vdisp') >= 0]
e_vdisp["Radius"] = e_vdisp["Radius"].astype(float)

#Only VROT, VDISP, INC and PA free, and INC BOUNDS [0,90]

vdisp_lin_360_incfree = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35_incfree/barbamodel/barbamodel_params.txt"
f = Table.read(vdisp_lin_360_incfree,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35_incfree/errors.txt"
f = Table.read(vdisp_lin_360_err,format='ascii')
f_vrot = f[np.char.find(f['Parameter'], 'vrot') >= 0]
f_vrot["Radius"] = f_vrot["Radius"].astype(float)
f_vdisp = f[np.char.find(f['Parameter'], 'vdisp') >= 0]
f_vdisp["Radius"] = f_vdisp["Radius"].astype(float)

# %%
#INCLINATION 70

#Only VROT and VDISP free

vdisp_lin_360 = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70/barbamodel/barbamodel_params.txt"
g = Table.read(vdisp_lin_360,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70/errors.txt"
g = Table.read(vdisp_lin_360_err,format='ascii')
g_vrot = g[np.char.find(g['Parameter'], 'vrot') >= 0]
g_vrot["Radius"] = g_vrot["Radius"].astype(float)
g_vdisp = g[np.char.find(g['Parameter'], 'vdisp') >= 0]
g_vdisp["Radius"] = g_vdisp["Radius"].astype(float)

#VROT, VDISP, INC, PA and CENTRE free

vdisp_lin_360_free = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70_free/barbamodel/barbamodel_params.txt"
h = Table.read(vdisp_lin_360_free,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70_free/errors.txt"
h = Table.read(vdisp_lin_360_err,format='ascii')
h_vrot = h[np.char.find(h['Parameter'], 'vrot') >= 0]
h_vrot["Radius"] = h_vrot["Radius"].astype(float)
h_vdisp = h[np.char.find(h['Parameter'], 'vdisp') >= 0]
h_vdisp["Radius"] = h_vdisp["Radius"].astype(float)

#Only VROT, VDISP, INC and PA free, and INC BOUNDS [0,90]

vdisp_lin_360_incfree = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70_incfree/barbamodel/barbamodel_params.txt"
i = Table.read(vdisp_lin_360_incfree,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70_incfree/errors.txt"
i = Table.read(vdisp_lin_360_err,format='ascii')
i_vrot = i[np.char.find(i['Parameter'], 'vrot') >= 0]
i_vrot["Radius"] = i_vrot["Radius"].astype(float)
i_vdisp = i[np.char.find(i['Parameter'], 'vdisp') >= 0]
i_vdisp["Radius"] = i_vdisp["Radius"].astype(float)

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

# Define offsets for clarity
offsets = [-20, -15, -10, -5, 0, 5, 10, 15, 20]

# Velocity curve plot
ax[0].plot(inpl['RADII'], inpl['VROT'], color='black', linewidth=2, label='input')
ax[0].errorbar(a_vrot["Radius"] + offsets[0], a_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[a_vrot["Error_Low"], a_vrot["Error_Up"]], label='fixed 51', color=col[0])
ax[0].errorbar(b_vrot["Radius"] + offsets[1], b_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[b_vrot["Error_Low"], b_vrot["Error_Up"]], label='free 51', color=col[1])
ax[0].errorbar(c_vrot["Radius"] + offsets[2], c_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[c_vrot["Error_Low"], c_vrot["Error_Up"]], label='inc free 51', color=col[2])
ax[0].errorbar(d_vrot["Radius"] + offsets[3], d_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[d_vrot["Error_Low"], d_vrot["Error_Up"]], label='fixed 35', color=col[3])
ax[0].errorbar(e_vrot["Radius"] + offsets[4], e_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[e_vrot["Error_Low"], e_vrot["Error_Up"]], label='free 35', color=col[4])
ax[0].errorbar(f_vrot["Radius"] + offsets[5], f_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[f_vrot["Error_Low"], f_vrot["Error_Up"]], label='inc free 35', color=col[5])
ax[0].errorbar(g_vrot["Radius"] + offsets[6], g_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[g_vrot["Error_Low"], g_vrot["Error_Up"]], label='fixed 70', color=col[6])
ax[0].errorbar(h_vrot["Radius"] + offsets[7], h_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[h_vrot["Error_Low"], h_vrot["Error_Up"]], label='free 70', color=col[7])
ax[0].errorbar(i_vrot["Radius"] + offsets[8], i_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[i_vrot["Error_Low"], i_vrot["Error_Up"]], label='inc free 70', color=col[8])
ax[0].set_xlabel('Radius (arcsec)')
ax[0].set_ylabel('Rotational velocity (km/s)')
ax[0].legend(fontsize="x-large")

# Dispersion plot
ax[1].plot(inpl['RADII'], inpl['VDISP'], color='black', linewidth=2, label='input')
ax[1].errorbar(a_vdisp["Radius"] + offsets[0], a_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[a_vdisp["Error_Low"], a_vdisp["Error_Up"]], label='fixed 51', color=col[0])
ax[1].errorbar(b_vdisp["Radius"] + offsets[1], b_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[b_vdisp["Error_Low"], b_vdisp["Error_Up"]], label='free 51', color=col[1])
ax[1].errorbar(c_vdisp["Radius"] + offsets[2], c_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[c_vdisp["Error_Low"], c_vdisp["Error_Up"]], label='inc free 51', color=col[2])
ax[1].errorbar(d_vdisp["Radius"] + offsets[3], d_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[d_vdisp["Error_Low"], d_vdisp["Error_Up"]], label='fixed 35', color=col[3])
ax[1].errorbar(e_vdisp["Radius"] + offsets[4], e_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[e_vdisp["Error_Low"], e_vdisp["Error_Up"]], label='free 35', color=col[4])
ax[1].errorbar(f_vdisp["Radius"] + offsets[5], f_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[f_vdisp["Error_Low"], f_vdisp["Error_Up"]], label='inc free 35', color=col[5])
ax[1].errorbar(g_vdisp["Radius"] + offsets[6], g_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[g_vdisp["Error_Low"], g_vdisp["Error_Up"]], label='fixed 70', color=col[6])
ax[1].errorbar(h_vdisp["Radius"] + offsets[7], h_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[h_vdisp["Error_Low"], h_vdisp["Error_Up"]], label='free 70', color=col[7])
ax[1].errorbar(i_vdisp["Radius"] + offsets[8], i_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[i_vdisp["Error_Low"], i_vdisp["Error_Up"]], label='inc free 70', color=col[8])
# ax[1].set_ylim(0, 40) # Uncomment if needed for clarity
ax[1].set_xlabel('Radius (arcsec)')
ax[1].set_ylabel('Dispersion velocity (km/s)')
ax[1].legend(fontsize="x-large")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## TESTS ON INCLINATION BOUNDS (LINEARLY DECREASING VELOCITY DISPERSION)

# %%
col=['#E41A1C', '#377EB8', '#4DAF4A', '#984EA3', '#FF7F00', '#FFFF33', '#A65628', '#F781BF', '#999999']
#INITIAL INCLINATION (50.988)

input_l_vdisp = "/Users/blanca/Documents/TESIS/software/code/models/model3_params.txt"
inpl = Table.read(input_l_vdisp,format='ascii')

#All parameters free but inc +/- 10

vdisp_lin_360_free = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_lin_360_free/barbamodel/barbamodel_params.txt"
a = Table.read(vdisp_lin_360_free,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/vdisp_test/vdisp_lin_360_free/errors.txt"
a = Table.read(vdisp_lin_360_err,format='ascii')
a_vrot = a[np.char.find(a['Parameter'], 'vrot') >= 0]
a_vrot["Radius"] = a_vrot["Radius"].astype(float)
a_vdisp = a[np.char.find(a['Parameter'], 'vdisp') >= 0]
a_vdisp["Radius"] = a_vdisp["Radius"].astype(float)

#All parameters free but inc +/- 20

inc_50988_20bound = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_50988_20bound/barbamodel/barbamodel_params.txt"
b = Table.read(inc_50988_20bound,format='ascii')
#ERROR CALCULATION
inc_50988_20bound_err = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_50988_20bound/errors.txt"
b = Table.read(inc_50988_20bound_err,format='ascii')
b_vrot = b[np.char.find(b['Parameter'], 'vrot') >= 0]
b_vrot["Radius"] = b_vrot["Radius"].astype(float)
b_vdisp = b[np.char.find(b['Parameter'], 'vdisp') >= 0]
b_vdisp["Radius"] = b_vdisp["Radius"].astype(float)

#All parameters free but inc +/- 30

inc_50988_30bound = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_50988_30bound/barbamodel/barbamodel_params.txt"
c = Table.read(inc_50988_30bound,format='ascii')
#ERROR CALCULATION
inc_50988_30bound_err = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_50988_30bound/errors.txt"
c = Table.read(inc_50988_30bound_err,format='ascii')
c_vrot = c[np.char.find(c['Parameter'], 'vrot') >= 0]
c_vrot["Radius"] = c_vrot["Radius"].astype(float)
c_vdisp = c[np.char.find(c['Parameter'], 'vdisp') >= 0]
c_vdisp["Radius"] = c_vdisp["Radius"].astype(float)

# %%
#INCLINATION 35

#All parameters free but inc +/- 10

vdisp_lin_360_35_free = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35_free/barbamodel/barbamodel_params.txt"
d = Table.read(vdisp_lin_360_35_free,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_35_free/errors.txt"
d = Table.read(vdisp_lin_360_err,format='ascii')
d_vrot = d[np.char.find(d['Parameter'], 'vrot') >= 0]
d_vrot["Radius"] = d_vrot["Radius"].astype(float)
d_vdisp = d[np.char.find(d['Parameter'], 'vdisp') >= 0]
d_vdisp["Radius"] = d_vdisp["Radius"].astype(float)

#All parameters free but inc +/- 20

inc_35_20bound = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_35_20bound/barbamodel/barbamodel_params.txt"
e = Table.read(inc_35_20bound,format='ascii')
#ERROR CALCULATION
inc_35_20bound_err = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_35_20bound/errors.txt"
e = Table.read(inc_35_20bound_err,format='ascii')
e_vrot = e[np.char.find(e['Parameter'], 'vrot') >= 0]
e_vrot["Radius"] = e_vrot["Radius"].astype(float)
e_vdisp = e[np.char.find(e['Parameter'], 'vdisp') >= 0]
e_vdisp["Radius"] = e_vdisp["Radius"].astype(float)

#All parameters free but inc +/- 30

inc_35_30bound = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_35_30bound/barbamodel/barbamodel_params.txt"
f = Table.read(inc_35_30bound,format='ascii')
#ERROR CALCULATION
inc_35_30bound_err = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_35_30bound/errors.txt"
f = Table.read(inc_35_30bound_err,format='ascii')
f_vrot = f[np.char.find(f['Parameter'], 'vrot') >= 0]
f_vrot["Radius"] = f_vrot["Radius"].astype(float)
f_vdisp = f[np.char.find(f['Parameter'], 'vdisp') >= 0]
f_vdisp["Radius"] = f_vdisp["Radius"].astype(float)

# %%
#INCLINATION 70

#All parameters free but inc +/- 10

vdisp_lin_360_70_free = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70_free/barbamodel/barbamodel_params.txt"
g = Table.read(vdisp_lin_360_70_free,format='ascii')
#ERROR CALCULATION
vdisp_lin_360_err = "/Users/blanca/Documents/TESIS/software/code/inc_test/vdisp_lin_360_70_free/errors.txt"
g = Table.read(vdisp_lin_360_err,format='ascii')
g_vrot = g[np.char.find(g['Parameter'], 'vrot') >= 0]
g_vrot["Radius"] = g_vrot["Radius"].astype(float)
g_vdisp = g[np.char.find(g['Parameter'], 'vdisp') >= 0]
g_vdisp["Radius"] = g_vdisp["Radius"].astype(float)

#All parameters free but inc +/- 20

inc_70_20bound = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_70_20bound/barbamodel/barbamodel_params.txt"
h = Table.read(inc_70_20bound,format='ascii')
#ERROR CALCULATION
inc_70_20bound_err = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_70_20bound/errors.txt"
h = Table.read(inc_70_20bound_err,format='ascii')
h_vrot = h[np.char.find(h['Parameter'], 'vrot') >= 0]
h_vrot["Radius"] = h_vrot["Radius"].astype(float)
h_vdisp = h[np.char.find(h['Parameter'], 'vdisp') >= 0]
h_vdisp["Radius"] = h_vdisp["Radius"].astype(float)

#All parameters free but inc +/- 30

inc_70_30bound = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_70_30bound/barbamodel/barbamodel_params.txt"
i = Table.read(inc_70_30bound,format='ascii')
#ERROR CALCULATION
inc_70_30bound_err = "/Users/blanca/Documents/TESIS/software/code/inc_bound_test/inc_70_30bound/errors.txt"
i = Table.read(inc_70_30bound_err,format='ascii')
i_vrot = i[np.char.find(i['Parameter'], 'vrot') >= 0]
i_vrot["Radius"] = i_vrot["Radius"].astype(float)
i_vdisp = i[np.char.find(i['Parameter'], 'vdisp') >= 0]
i_vdisp["Radius"] = i_vdisp["Radius"].astype(float)

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

# Define offsets for clarity
offsets = [-20, -15, -10, -5, 0, 5, 10, 15, 20]

# Velocity curve plot
ax[0].plot(inpl['RADII'], inpl['VROT'], color='black', linewidth=2, label='input')
ax[0].errorbar(a_vrot["Radius"] + offsets[0], a_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[a_vrot["Error_Low"], a_vrot["Error_Up"]], label=r'51 $\pm$ 10', color=col[0])
ax[0].errorbar(b_vrot["Radius"] + offsets[1], b_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[b_vrot["Error_Low"], b_vrot["Error_Up"]], label=r'51 $\pm$ 20', color=col[1])
ax[0].errorbar(c_vrot["Radius"] + offsets[2], c_vrot["Median"], capsize=5, fmt='o', markersize=7,yerr=[c_vrot["Error_Low"], c_vrot["Error_Up"]], label=r'51 $\pm$ 30', color=col[2])
ax[0].errorbar(d_vrot["Radius"] + offsets[3], d_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[d_vrot["Error_Low"], d_vrot["Error_Up"]], label=r'35 $\pm$ 10', color=col[3])
ax[0].errorbar(e_vrot["Radius"] + offsets[4], e_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[e_vrot["Error_Low"], e_vrot["Error_Up"]], label=r'35 $\pm$ 20', color=col[4])
ax[0].errorbar(f_vrot["Radius"] + offsets[5], f_vrot["Median"], capsize=5, fmt='*', markersize=7,yerr=[f_vrot["Error_Low"], f_vrot["Error_Up"]], label=r'35 $\pm$ 30', color=col[5])
ax[0].errorbar(g_vrot["Radius"] + offsets[6], g_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[g_vrot["Error_Low"], g_vrot["Error_Up"]], label=r'70 $\pm$ 10', color=col[6])
ax[0].errorbar(h_vrot["Radius"] + offsets[7], h_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[h_vrot["Error_Low"], h_vrot["Error_Up"]], label=r'70 $\pm$ 20', color=col[7])
ax[0].errorbar(i_vrot["Radius"] + offsets[8], i_vrot["Median"], capsize=5, fmt='s', markersize=7,yerr=[i_vrot["Error_Low"], i_vrot["Error_Up"]], label=r'70 $\pm$ 30', color=col[8])
ax[0].set_xlabel('Radius (arcsec)')
ax[0].set_ylabel('Rotational velocity (km/s)')
ax[0].legend(fontsize="x-large")

# Dispersion plot
ax[1].plot(inpl['RADII'], inpl['VDISP'], color='black', linewidth=2, label='input')
ax[1].errorbar(a_vdisp["Radius"] + offsets[0], a_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[a_vdisp["Error_Low"], a_vdisp["Error_Up"]], label=r'51 $\pm$ 10', color=col[0])
ax[1].errorbar(b_vdisp["Radius"] + offsets[1], b_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[b_vdisp["Error_Low"], b_vdisp["Error_Up"]], label=r'51 $\pm$ 20', color=col[1])
ax[1].errorbar(c_vdisp["Radius"] + offsets[2], c_vdisp["Median"], capsize=5, fmt='o', markersize=7,yerr=[c_vdisp["Error_Low"], c_vdisp["Error_Up"]], label=r'51 $\pm$ 30', color=col[2])
ax[1].errorbar(d_vdisp["Radius"] + offsets[3], d_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[d_vdisp["Error_Low"], d_vdisp["Error_Up"]], label=r'35 $\pm$ 10', color=col[3])
ax[1].errorbar(e_vdisp["Radius"] + offsets[4], e_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[e_vdisp["Error_Low"], e_vdisp["Error_Up"]], label=r'35 $\pm$ 20', color=col[4])
ax[1].errorbar(f_vdisp["Radius"] + offsets[5], f_vdisp["Median"], capsize=5, fmt='*', markersize=7,yerr=[f_vdisp["Error_Low"], f_vdisp["Error_Up"]], label=r'35 $\pm$ 30', color=col[5])
ax[1].errorbar(g_vdisp["Radius"] + offsets[6], g_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[g_vdisp["Error_Low"], g_vdisp["Error_Up"]], label=r'70 $\pm$ 10', color=col[6])
ax[1].errorbar(h_vdisp["Radius"] + offsets[7], h_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[h_vdisp["Error_Low"], h_vdisp["Error_Up"]], label=r'70 $\pm$ 20', color=col[7])
ax[1].errorbar(i_vdisp["Radius"] + offsets[8], i_vdisp["Median"], capsize=5, fmt='s', markersize=7,yerr=[i_vdisp["Error_Low"], i_vdisp["Error_Up"]], label=r'70 $\pm$ 30', color=col[8])
# ax[1].set_ylim(0, 40) # Uncomment if needed for clarity
ax[1].set_xlabel('Radius (arcsec)')
ax[1].set_ylabel('Dispersion velocity (km/s)')
ax[1].legend(fontsize="x-large")

plt.tight_layout()
plt.show()
