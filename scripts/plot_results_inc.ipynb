# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table

# %%
input_inc30 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc30/velset_inc30_params.txt"
inc30 = Table.read(input_inc30,format='ascii')
inc30_i = inc30["INC"]
radii = inc30["RADII"]

rec_inc30 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc30/barbamodel/barbamodel_params.txt"
inc30r = Table.read(rec_inc30,format='ascii')
inc30_r = inc30r["INC"]
radiii = inc30r["RADII"]

input_inc35 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc35/velset_inc35_params.txt"
inc35 = Table.read(input_inc35,format='ascii')
inc35_i = inc35["INC"]

rec_inc35 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc35/barbamodel/barbamodel_params.txt"
inc35r = Table.read(rec_inc35,format='ascii')
inc35_r = inc35r["INC"]

input_inc40 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc40/velset_inc40_params.txt"
inc40 = Table.read(input_inc40,format='ascii')
inc40_i = inc40["INC"]

rec_inc40 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc40/barbamodel/barbamodel_params.txt"
inc40r = Table.read(rec_inc40,format='ascii')
inc40_r = inc40r["INC"]

input_inc45 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc45/velset_inc45_params.txt"
inc45 = Table.read(input_inc45,format='ascii')
inc45_i = inc45["INC"]

rec_inc45 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc45/barbamodel/barbamodel_params.txt"
inc45r = Table.read(rec_inc45,format='ascii')
inc45_r = inc45r["INC"]

input_inc50 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc50/velset_inc50_params.txt"
inc50 = Table.read(input_inc50,format='ascii')
inc50_i = inc50["INC"]

rec_inc50 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc50/barbamodel/barbamodel_params.txt"
inc50r = Table.read(rec_inc50,format='ascii')
inc50_r = inc50r["INC"]

input_inc55 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc55/velset_inc55_params.txt"
inc55 = Table.read(input_inc55,format='ascii')
inc55_i = inc55["INC"]

rec_inc55 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc55/barbamodel/barbamodel_params.txt"
inc55r = Table.read(rec_inc55,format='ascii')
inc55_r = inc55r["INC"]

input_inc60 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc60/velset_inc60_params.txt"
inc60 = Table.read(input_inc60,format='ascii')
inc60_i = inc60["INC"]

rec_inc60 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc60/barbamodel/barbamodel_params.txt"
inc60r = Table.read(rec_inc60,format='ascii')
inc60_r = inc60r["INC"]

input_inc65 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc65/velset_inc65_params.txt"
inc65 = Table.read(input_inc65,format='ascii')
inc65_i = inc65["INC"]

rec_inc65 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc65/barbamodel/barbamodel_params.txt"
inc65r = Table.read(rec_inc65,format='ascii')
inc65_r = inc65r["INC"]

input_inc70 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc70/velset_inc70_params.txt"
inc70 = Table.read(input_inc70,format='ascii')
inc70_i = inc70["INC"]

rec_inc70 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc70/barbamodel/barbamodel_params.txt"
inc70r = Table.read(rec_inc70,format='ascii')
inc70_r = inc70r["INC"]

input_inc75 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc75/velset_inc75_params.txt"
#inc75 = Table.read(input_inc75,format='ascii')
#inc75_i = inc75["INC"]

#rec_inc75 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc75/barbamodel/barbamodel_params.txt"
#inc75r = Table.read(rec_inc75,format='ascii')
#inc75_r = inc75r["INC"]

# %%
colors = plt.cm.tab10(np.linspace(0, 1, 10))  # Use tab10 for distinct colors

# Create the plot
plt.figure(figsize=(10, 6))

# Explicitly plot each input and recovered value pair
plt.plot(radii, np.full_like(radii, inc30_i), label=f"Inclination 30: Input", color=colors[0], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc30_r), label=f"Inclination 30: Recovered", color=colors[0], linestyle='--')

plt.plot(radii, np.full_like(radii, inc35_i), label=f"Inclination 35: Input", color=colors[1], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc35_r), label=f"Inclination 35: Recovered", color=colors[1], linestyle='--')

plt.plot(radii, np.full_like(radii, inc40_i), label=f"Inclination 40: Input", color=colors[2], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc40_r), label=f"Inclination 40: Recovered", color=colors[2], linestyle='--')

plt.plot(radii, np.full_like(radii, inc45_i), label=f"Inclination 45: Input", color=colors[3], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc45_r), label=f"Inclination 45: Recovered", color=colors[3], linestyle='--')

plt.plot(radii, np.full_like(radii, inc50_i), label=f"Inclination 50: Input", color=colors[4], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc50_r), label=f"Inclination 50: Recovered", color=colors[4], linestyle='--')

plt.plot(radii, np.full_like(radii, inc55_i), label=f"Inclination 55: Input", color=colors[5], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc55_r), label=f"Inclination 55: Recovered", color=colors[5], linestyle='--')

plt.plot(radii, np.full_like(radii, inc60_i), label=f"Inclination 60: Input", color=colors[6], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc60_r), label=f"Inclination 60: Recovered", color=colors[6], linestyle='--')

plt.plot(radii, np.full_like(radii, inc65_i), label=f"Inclination 65: Input", color=colors[7], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc65_r), label=f"Inclination 65: Recovered", color=colors[7], linestyle='--')

plt.plot(radii, np.full_like(radii, inc70_i), label=f"Inclination 70: Input", color=colors[8], linestyle='-')
plt.plot(radiii, np.full_like(radiii, inc70_r), label=f"Inclination 70: Recovered", color=colors[8], linestyle='--')

#plt.plot(radii, np.full_like(radii, inc75_i), label=f"Inclination 75: Input", color=colors[9], linestyle='-')
#plt.plot(radii, np.full_like(radii, inc75_r), label=f"Inclination 75: Recovered", color=colors[9], linestyle='--')

# Customizing the plot
plt.xlabel("Radius")
plt.ylabel("Inclination")
plt.title("Input vs Recovered Values for Inclinations")
plt.legend(loc="upper left", bbox_to_anchor=(1.05, 1), title="Inclinations")
plt.tight_layout()

# Show the plot
plt.show()

# %%
input_inc30 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc30/velset_inc30_params.txt"
inc30 = Table.read(input_inc30,format='ascii')
inc30_i = np.mean(inc30["INC"])


rec_inc30 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc30/errors.txt"
inc30r = Table.read(rec_inc30,format='ascii')
inc30_r = inc30r[np.char.find(inc30r['Parameter'], 'inc') >= 0]
print(inc30_r["Median"])


input_inc35 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc35/velset_inc35_params.txt"
inc35 = Table.read(input_inc35,format='ascii')
inc35_i = np.mean(inc35["INC"])

rec_inc35 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc35/errors.txt"
inc35r = Table.read(rec_inc35,format='ascii')
inc35_r = inc35r[np.char.find(inc35r['Parameter'], 'inc') >= 0]

input_inc40 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc40/velset_inc40_params.txt"
inc40 = Table.read(input_inc40,format='ascii')
inc40_i = np.mean(inc40["INC"])


rec_inc40 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc40/errors.txt"
inc40r = Table.read(rec_inc40,format='ascii')
inc40_r = inc40r[np.char.find(inc40r['Parameter'], 'inc') >= 0]

input_inc45 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc45/velset_inc45_params.txt"
inc45 = Table.read(input_inc45,format='ascii')
inc45_i = np.mean(inc45["INC"])

rec_inc45 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc45/errors.txt"
inc45r = Table.read(rec_inc45,format='ascii')
inc45_r = inc45r[np.char.find(inc45r['Parameter'], 'inc') >= 0]

input_inc50 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc50/velset_inc50_params.txt"
inc50 = Table.read(input_inc50,format='ascii')
inc50_i = np.mean(inc50["INC"])

rec_inc50 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc50/errors.txt"
inc50r = Table.read(rec_inc50,format='ascii')
inc50_r = inc50r[np.char.find(inc50r['Parameter'], 'inc') >= 0]

input_inc55 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc55/velset_inc55_params.txt"
inc55 = Table.read(input_inc55,format='ascii')
inc55_i = np.mean(inc55["INC"])

rec_inc55 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc55/errors.txt"
inc55r = Table.read(rec_inc55,format='ascii')
inc55_r = inc55r[np.char.find(inc55r['Parameter'], 'inc') >= 0]

input_inc60 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc60/velset_inc60_params.txt"
inc60 = Table.read(input_inc60,format='ascii')
inc60_i = np.mean(inc60["INC"])

rec_inc60 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc60/errors.txt"
inc60r = Table.read(rec_inc60,format='ascii')
inc60_r = inc60r[np.char.find(inc60r['Parameter'], 'inc') >= 0]

input_inc65 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc65/velset_inc65_params.txt"
inc65 = Table.read(input_inc65,format='ascii')
inc65_i = np.mean(inc65["INC"])

rec_inc65 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc65/errors.txt"
inc65r = Table.read(rec_inc65,format='ascii')
inc65_r = inc65r[np.char.find(inc65r['Parameter'], 'inc') >= 0]

input_inc70 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc70/velset_inc70_params.txt"
inc70 = Table.read(input_inc70,format='ascii')
inc70_i = np.mean(inc70["INC"])

rec_inc70 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc70/errors.txt"
inc70r = Table.read(rec_inc70,format='ascii')
inc70_r = inc70r[np.char.find(inc70r['Parameter'], 'inc') >= 0]

input_inc75 = "/Users/blanca/Documents/TESIS/software/code/models/velset_inc75/velset_inc75_params.txt"
inc75 = Table.read(input_inc75,format='ascii')
inc75_i = np.mean(inc75["INC"])

rec_inc75 = "/Users/blanca/Documents/TESIS/software/code/TESTS/tests_inc/velset_inc75/errors.txt"
inc75r = Table.read(rec_inc75,format='ascii')
inc75_r = inc75r[np.char.find(inc75r['Parameter'], 'inc') >= 0]
# Out:
#   Median
# ---------
# 30.686208

# %%
col = plt.cm.tab10(np.linspace(0, 1, 10))  # Use tab10 for distinct colors
imput = [30,35,40,45,50,55,60,65,70,75]
plt.figure(figsize=(10, 6))
plt.errorbar(30, inc30_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc30_r['Error_Low'], inc30_r['Error_Up']], color=col[0])
plt.errorbar(35, inc35_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc35_r['Error_Low'], inc35_r['Error_Up']], color=col[1])
plt.errorbar(40, inc40_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc40_r['Error_Low'], inc40_r['Error_Up']], color=col[2])
plt.errorbar(45, inc45_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc45_r['Error_Low'], inc45_r['Error_Up']], color=col[3])
plt.errorbar(50, inc50_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc50_r['Error_Low'], inc50_r['Error_Up']], color=col[4])
plt.errorbar(55, inc55_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc55_r['Error_Low'], inc55_r['Error_Up']], color=col[5])
plt.errorbar(60, inc60_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc60_r['Error_Low'], inc60_r['Error_Up']], color=col[6])
plt.errorbar(65, inc65_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc65_r['Error_Low'], inc65_r['Error_Up']], color=col[7])
plt.errorbar(70, inc70_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc70_r['Error_Low'], inc70_r['Error_Up']], color=col[8])
plt.errorbar(75, inc75_r['Median'], capsize=5, fmt='o', markersize=7,yerr=[inc75_r['Error_Low'], inc75_r['Error_Up']], color=col[9])

plt.plot(imput, imput, 'k--')
plt.xlabel('Inclination')
plt.ylabel('Inclination')
plt.title('Input vs Recovered Values for Inclinations')
plt.tight_layout()

# Show the plot
plt.show()
